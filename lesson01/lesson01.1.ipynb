# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(-2*np.pi, 2*np.pi, 400)
y1 = np.cos(x)
y2 = np.cos(3*x)
plt.plot(x, y1)
plt.plot(x, y2)
plt.axis('tight')
plt.xlabel('X, Angle [rad]')
plt.ylabel('Y = cos(kx)')
plt.show()
